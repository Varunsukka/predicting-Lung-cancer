# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\Rishivarun\\Downloads\\lungcancer\\lung.csv")

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
data.style.highlight_null()
# Out:
# <style  type="text/css" >
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
print(round(data.corr(),2))
# Out:
#                         AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# AGE                    1.00    -0.08            0.01     0.05           0.02
# SMOKING               -0.08     1.00           -0.01     0.16          -0.04
# YELLOW_FINGERS         0.01    -0.01            1.00     0.57           0.32
# ANXIETY                0.05     0.16            0.57     1.00           0.22
# PEER_PRESSURE          0.02    -0.04            0.32     0.22           1.00
# CHRONIC DISEASE       -0.01    -0.14            0.04    -0.01           0.05
# FATIGUE                0.01    -0.03           -0.12    -0.19           0.08
# ALLERGY                0.03     0.00           -0.14    -0.17          -0.08
# WHEEZING               0.06    -0.13           -0.08    -0.19          -0.07
# ALCOHOL CONSUMING      0.06    -0.05           -0.29    -0.17          -0.16
# COUGHING               0.17    -0.13           -0.01    -0.23          -0.09
# ...

# %%
dataplot = sb.heatmap(round(data.corr(),2), cmap="YlGnBu", annot=True)

# %%
plt.style.use("seaborn")
data.hist(figsize=(25,25), bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'SMOKING'}>,
#         <AxesSubplot:title={'center':'YELLOW_FINGERS'}>,
#         <AxesSubplot:title={'center':'ANXIETY'}>],
#        [<AxesSubplot:title={'center':'PEER_PRESSURE'}>,
#         <AxesSubplot:title={'center':'CHRONIC DISEASE'}>,
#         <AxesSubplot:title={'center':'FATIGUE '}>,
#         <AxesSubplot:title={'center':'ALLERGY '}>],
#        [<AxesSubplot:title={'center':'WHEEZING'}>,
#         <AxesSubplot:title={'center':'ALCOHOL CONSUMING'}>,
#         <AxesSubplot:title={'center':'COUGHING'}>,
#         <AxesSubplot:title={'center':'SHORTNESS OF BREATH'}>],
#        [<AxesSubplot:title={'center':'SWALLOWING DIFFICULTY'}>,
#         <AxesSubplot:title={'center':'CHEST PAIN'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sb.countplot(x='AGE',hue='LUNG_CANCER',data=data)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %%
sb.countplot(x='CHRONIC DISEASE',hue='LUNG_CANCER',data=data)
# Out:
# <AxesSubplot:xlabel='CHRONIC DISEASE', ylabel='count'>

# %%
sb.countplot(x='GENDER',hue='LUNG_CANCER',data=data)
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
sb.histplot(data[['AGE', 'GENDER']], x = "AGE", hue="GENDER")
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %%
data.replace({'F': 0, 'M': 1}, inplace=True)
data.replace({'YES': 2, 'NO': 1}, inplace=True)
x = data.drop("LUNG_CANCER", axis = 1)
y = data["LUNG_CANCER"]
data[1:2]
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1       1   74        2               1        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 1                2         2         2         1                  1         1
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 1                    2                      2           2            2

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y , test_size = 0.2, random_state=47)

# %%
from sklearn.preprocessing import StandardScaler

# %%
plt.figure(figsize=(20,8))
plt.title("Before Scaling", y=1.0)
sb.boxenplot(data=x_train)
plt.show()

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
z=x_test[:,1:2]

# %%
plt.figure(figsize=(20,8))
plt.title("After Scaling", y=1.0)
sb.boxenplot(data=x_train)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
y_pred = clf.predict(x_test)
acc=accuracy_score(y_test, y_pred)
mse=mean_squared_error(y_test, y_pred)
mae=mean_absolute_error(y_test, y_pred)
mape=mean_absolute_percentage_error(y_test, y_pred)

# %%
acc
# Out:
# 0.9354838709677419

# %%
print(mse)
# Out:
# 0.06451612903225806

# %%
print(mae)
print(mape)
# Out:
# 0.06451612903225806
# 0.056451612903225805

# %%
#from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#model = BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=100)

# %%
#model.fit(x_train,y_train)

# %%
#y_pred1 = model.predict(x_test)
#acc1=accuracy_score(y_test, y_pred1)

# %%
#acc1

# %%
#y_test

# %%
#mean_absolute_error(y_test, y_pred1)

# %%
plt.scatter(z,y_test,color='r', label='actual test values')
plt.scatter(z,y_pred,color='b', label='Predicted test values', marker='+')
plt.xlabel('age')
plt.ylabel('lung cancer')
plt.legend()
plt.show()

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf, x_test, y_test)  
plt.show()

# %%
from sklearn import metrics
metrics.plot_roc_curve(clf, x_test, y_test)
plt.show()

# %%
plt.figure(figsize=(5,5))
_ = tree.plot_tree(clf.estimators_[1], feature_names=x.columns, filled=True)

# %%
plt.figure(figsize=(5,5))
_ = tree.plot_tree(clf.estimators_[2], feature_names=x.columns, filled=True)

# %%
model2 = DecisionTreeClassifier(random_state=23)

# %%
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=23)

# %%
y_pred2 = model2.predict(x_test)
acc2=accuracy_score(y_test, y_pred2)
mse2=mean_squared_error(y_test, y_pred2)
mae2=mean_absolute_error(y_test, y_pred2)
mape2=mean_absolute_percentage_error(y_test, y_pred2)

# %%
acc2
# Out:
# 0.9032258064516129

# %%
mse2
# Out:
# 0.0967741935483871

# %%
mae2
# Out:
# 0.0967741935483871

# %%
mape2
# Out:
# 0.07258064516129033
